# %%
import pandas as pd
import sqlite3

# Read the CSV file into a DataFrame
df = pd.read_csv('country.csv')

# Create a connection to the SQLite database
conn = sqlite3.connect('database.db')

# Use the DataFrame.to_sql() method to create a new table in the database and populate it with the data from the DataFrame
df.to_sql('country', conn, if_exists='replace', index=False)
# Out:
# 237673

# %%
df = pd.read_csv('match.csv')
df.to_sql('match', conn, if_exists='replace', index=False)
# Out:
# 237673

# %%
df = pd.read_csv('medal_type.csv')
df.to_sql('medal_type', conn, if_exists='replace', index=False)
# Out:
# 237673

# %%
df = pd.read_csv('player.csv')
df.to_sql('player', conn, if_exists='replace', index=False)
# Out:
# 237673

# %%
# %load_ext sql
# %sql sqlite:///database.db

# %% [markdown]
# # This is a historical dataset on the modern Olympic Games, including all the Games from Athens 1896 to Tokyo 2020.

# %% [markdown]
# # This dataset contains 237673 rows and we splitted it to 4 tables.
# ## Now we want to run some simple SQL queries.

# %% [markdown]
# ### 1. SQL query that selects all the distinct values of the "Sport" column

# %%
# %%sql
# select distinct(sport)
# from match
# order by sport
# Out:
# *  sqlite:///database.db
# Done.
# [('3x3 Basketball',),
#  ('Aeronautics',),
#  ('Alpinism',),
#  ('Archery',),
#  ('Art Competitions',),
#  ('Artistic Gymnastics',),
#  ('Artistic Swimming',),
#  ('Athletics',),
#  ('Badminton',),
#  ('Baseball',),
#  ('Baseball/Softball',),
#  ('Basketball',),
#  ('Basque Pelota',),
#  ('Beach Volleyball',),
#  ('Boxing',),
#  ('Canoe Slalom',),
#  ('Canoe Sprint',),
#  ('Canoeing',),
#  ('Cricket',),
#  ('Croquet',),
#  ('Cycling',),
#  ('Cycling BMX Freestyle',),
#  ('Cycling BMX Racing',),
#  ('Cycling Mountain Bike',),
#  ('Cycling Road',),
#  ('Cycling Track',),
#  ('Diving',),
#  ('Equestrian',),
#  ('Equestrianism',),
#  ('Fencing',),
#  ('Figure Skating',),
#  ('Football',),
#  ('Golf',),
#  ('Gymnastics',),
#  ('Handball',),
#  ('Hockey',),
#  ('Ice Hockey',),
#  ('Jeu De Paume',),
#  ('Judo',),
#  ('Karate',),
#  ('Lacrosse',),
#  ('Marathon Swimming',),
#  ('Modern Pentathlon',),
#  ('Motorboating',),
#  ('Polo',),
#  ('Racquets',),
#  ('Rhythmic Gymnastics',),
#  ('Roque',),
#  ('Rowing',),
#  ('Rugby',),
#  ('Rugby Sevens',),
#  ('Sailing',),
#  ('Shooting',),
#  ('Skateboarding',),
#  ('Softball',),
#  ('Sport Climbing',),
#  ('Surfing',),
#  ('Swimming',),
#  ('Synchronized Swimming',),
#  ('Table Tennis',),
#  ('Taekwondo',),
#  ('Tennis',),
#  ('Trampoline Gymnastics',),
#  ('Trampolining',),
#  ('Triathlon',),
#  ('Tug-Of-War',),
#  ('Volleyball',),
#  ('Water Polo',),
#  ('Weightlifting',),
#  ('Wrestling',)]

# %% [markdown]
# ### 2. SQL query that selects maximum and minimum ages of female players

# %%
# %%sql
# select max(age),min(age)
# from Player
# where Sex='F'
# order by Age desc
# limit 5;
# Out:
# *  sqlite:///database.db
# Done.
# [(74.0, 11.0)]

# %% [markdown]
# ### 3. SQL query that selects total medals by year.

# %%
# %%sql
# select count(*) ,medal,year
# from Medal_type
# where medal is not null
# group by medal,year
# order by year desc
# limit 20;
# Out:
# *  sqlite:///database.db
# Done.
# [(867, 'Bronze', 2020),
#  (800, 'Gold', 2020),
#  (782, 'Silver', 2020),
#  (703, 'Bronze', 2016),
#  (665, 'Gold', 2016),
#  (655, 'Silver', 2016),
#  (679, 'Bronze', 2012),
#  (632, 'Gold', 2012),
#  (630, 'Silver', 2012),
#  (710, 'Bronze', 2008),
#  (671, 'Gold', 2008),
#  (667, 'Silver', 2008),
#  (677, 'Bronze', 2004),
#  (664, 'Gold', 2004),
#  (660, 'Silver', 2004),
#  (680, 'Bronze', 2000),
#  (663, 'Gold', 2000),
#  (661, 'Silver', 2000),
#  (629, 'Bronze', 1996),
#  (608, 'Gold', 1996)]

# %% [markdown]
# ### 4. SQL query that selects count of events by year

# %%
# %%sql
# select year,count(event)
# from Match,Medal_type
# where match.player_id=Medal_type.player_id
# group by year
# order by year desc
# limit 20;
# Out:
# *  sqlite:///database.db
# Done.
# [(2020, 28004),
#  (2016, 14591),
#  (2012, 13722),
#  (2008, 14394),
#  (2004, 14215),
#  (2000, 14636),
#  (1996, 14585),
#  (1992, 13714),
#  (1988, 12799),
#  (1984, 10070),
#  (1980, 7665),
#  (1976, 9137),
#  (1972, 10961),
#  (1968, 9139),
#  (1964, 8137),
#  (1960, 8609),
#  (1956, 5372),
#  (1952, 8711),
#  (1948, 6816),
#  (1936, 6803)]

# %% [markdown]
# ### 5. SQL query that selects the winers that recieved gold medals in 1996. return the name of participants,the countries and the events.

# %%
# %%sql
# select Name,team,Event
# from country,Medal_type,Match,Player
# where country.team_id =Medal_type.player_id
# And Medal_type.player_id=match.player_id
# And match.player_id=player.player_id
# And medal='Gold'
# and year=1996;
# Out:
# *  sqlite:///database.db
# Done.
# [('AGUIAR Mayra', 'Brazil', 'Mixed Team'),
#  ('Jos Mara Abarca Plotas', 'Brazil', 'Mixed Team'),
#  ('AGUIAR Mayra', 'Brazil', "Water Polo Men's Water Polo"),
#  ('Jos Mara Abarca Plotas', 'Brazil', "Water Polo Men's Water Polo"),
#  ('AGUIAR Mayra', 'Spain', 'Mixed Team'),
#  ('Jos Mara Abarca Plotas', 'Spain', 'Mixed Team'),
#  ('AGUIAR Mayra', 'Spain', "Water Polo Men's Water Polo"),
#  ('Jos Mara Abarca Plotas', 'Spain', "Water Polo Men's Water Polo"),
#  ('AIT DAOUD Kamel', 'Algeria', "Lightweight Men's Double Sculls Team"),
#  ('Agostino Abbagnale', 'Algeria', "Lightweight Men's Double Sculls Team"),
#  ('AIT DAOUD Kamel', 'Algeria', "Rowing Men's Double Sculls"),
#  ('Agostino Abbagnale', 'Algeria', "Rowing Men's Double Sculls"),
#  ('AIT DAOUD Kamel', 'Italy', "Lightweight Men's Double Sculls Team"),
#  ('Agostino Abbagnale', 'Italy', "Lightweight Men's Double Sculls Team"),
#  ('AIT DAOUD Kamel', 'Italy', "Rowing Men's Double Sculls"),
#  ('Agostino Abbagnale', 'Italy', "Rowing Men's Double Sculls"),
#  ('BRNOVIC Tatjana', 'France-1', "Canoeing Men's Canadian Doubles, Slalom"),
#  ('Franck Adisson', 'France-1', "Canoeing Men's Canadian Doubles, Slalom"),
#  ('BRNOVIC Tatjana', 'France-1', 'Women Team'),
#  ('Franck Adisson', 'France-1', 'Women Team'),
#  ('BRNOVIC Tatjana', 'Montenegro', "Canoeing Men's Canadian Doubles, Slalom"),
#  ('Franck Adisson', 'Montenegro', "Canoeing Men's Canadian Doubles, Slalom"),
#  ('BRNOVIC Tatjana', 'Montenegro', 'Women Team'),
#  ('Franck Adisson', 'Montenegro', 'Women Team'),
#  ('BROMELL Trayvon', 'United States', "Athletics Men's 400 metres Hurdles"),
#  ('Derrick Ralph Adkins', 'United States', "Athletics Men's 400 metres Hurdles"),
#  ('BROMELL Trayvon', 'United States', "Men's 100m"),
#  ('Derrick Ralph Adkins', 'United States', "Men's 100m"),
#  ('BROMELL Trayvon', 'United States', "Athletics Men's 400 metres Hurdles"),
#  ('Derrick Ralph Adkins', 'United States', "Athletics Men's 400 metres Hurdles"),
#  ('BROMELL Trayvon', 'United States', "Men's 100m"),
#  ('Derrick Ralph Adkins', 'United States', "Men's 100m"),
#  ('Andre Kirk Agassi', 'Italy', "Tennis Men's Singles"),
#  ('CARINI Angela', 'Italy', "Tennis Men's Singles"),
#  ('Andre Kirk Agassi', 'Italy', "Women's Welter (64-69kg)"),
#  ('CARINI Angela', 'Italy', "Women's Welter (64-69kg)"),
#  ('Andre Kirk Agassi', 'United States', "Tennis Men's Singles"),
#  ('CARINI Angela', 'United States', "Tennis Men's Singles"),
#  ('Andre Kirk Agassi', 'United States', "Women's Welter (64-69kg)"),
#  ('CARINI Angela', 'United States', "Women's Welter (64-69kg)"),
#  ('DAL MOLIN Paolo', 'Cuba', "Baseball Men's Baseball"),
#  ('Omar Ajete Iglesias', 'Cuba', "Baseball Men's Baseball"),
#  ('DAL MOLIN Paolo', 'Cuba', "Men's 110m Hurdles"),
#  ('Omar Ajete Iglesias', 'Cuba', "Men's 110m Hurdles"),
#  ('DAL MOLIN Paolo', 'Italy', "Baseball Men's Baseball"),
#  ('Omar Ajete Iglesias', 'Italy', "Baseball Men's Baseball"),
#  ('DAL MOLIN Paolo', 'Italy', "Men's 110m Hurdles"),
#  ('Omar Ajete Iglesias', 'Italy', "Men's 110m Hurdles"),
#  ('Chioma Ajunwa (-Opara)', 'Brazil', "Athletics Women's Long Jump"),
#  ("D'ALMEIDA Marcus", 'Brazil', "Athletics Women's Long Jump"),
#  ('Chioma Ajunwa (-Opara)', 'Brazil', "Men's Individual"),
#  ("D'ALMEIDA Marcus", 'Brazil', "Men's Individual"),
#  ('Chioma Ajunwa (-Opara)', 'Nigeria', "Athletics Women's Long Jump"),
#  ("D'ALMEIDA Marcus", 'Nigeria', "Athletics Women's Long Jump"),
#  ('Chioma Ajunwa (-Opara)', 'Nigeria', "Men's Individual"),
#  ("D'ALMEIDA Marcus", 'Nigeria', "Men's Individual"),
#  ('DAWSON Jacob', 'Great Britain', "Football Women's Football"),
#  ('Michelle Anne Akers', 'Great Britain', "Football Women's Football"),
#  ('DAWSON Jacob', 'Great Britain', "Men's Eight Team"),
#  ('Michelle Anne Akers', 'Great Britain', "Men's Eight Team"),
#  ('DAWSON Jacob', 'United States', "Football Women's Football"),
#  ('Michelle Anne Akers', 'United States', "Football Women's Football"),
#  ('DAWSON Jacob', 'United States', "Men's Eight Team"),
#  ('Michelle Anne Akers', 'United States', "Men's Eight Team"),
#  ('IVOVIC Aleksandar', 'Montenegro', "Gymnastics Women's Horse Vault"),
#  ('Simona Amnar (-Tabr)', 'Montenegro', "Gymnastics Women's Horse Vault"),
#  ('IVOVIC Aleksandar', 'Montenegro', 'Men Team'),
#  ('Simona Amnar (-Tabr)', 'Montenegro', 'Men Team'),
#  ('IVOVIC Aleksandar', 'Romania', "Gymnastics Women's Horse Vault"),
#  ('Simona Amnar (-Tabr)', 'Romania', "Gymnastics Women's Horse Vault"),
#  ('IVOVIC Aleksandar', 'Romania', 'Men Team'),
#  ('Simona Amnar (-Tabr)', 'Romania', 'Men Team'),
#  ('JANG Woojin', 'France', "Men's Singles"),
#  ('Jean-Pierre Bernard Andr Amat', 'France', "Men's Singles"),
#  ('JANG Woojin', 'France', "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"),
#  ('Jean-Pierre Bernard Andr Amat', 'France', "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"),
#  ('JANG Woojin', 'South Korea', "Men's Singles"),
#  ('Jean-Pierre Bernard Andr Amat', 'South Korea', "Men's Singles"),
#  ('JANG Woojin', 'South Korea', "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"),
#  ('Jean-Pierre Bernard Andr Amat', 'South Korea', "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"),
#  ('Daniel Owofin Amokachi', 'Estonia', "Football Men's Football"),
#  ('KANGERT Tanel', 'Estonia', "Football Men's Football"),
#  ('Daniel Owofin Amokachi', 'Estonia', "Men's Road Race"),
#  ('KANGERT Tanel', 'Estonia', "Men's Road Race"),
#  ('Daniel Owofin Amokachi', 'Nigeria', "Football Men's Football"),
#  ('KANGERT Tanel', 'Nigeria', "Football Men's Football"),
#  ('Daniel Owofin Amokachi', 'Nigeria', "Men's Road Race"),
#  ('KANGERT Tanel', 'Nigeria', "Men's Road Race"),
#  ('Emmanuel Amunike', 'Nigeria', "Football Men's Football"),
#  ('KELDIYOROVA Diyora', 'Nigeria', "Football Men's Football"),
#  ('Emmanuel Amunike', 'Nigeria', 'Women -52 kg'),
#  ('KELDIYOROVA Diyora', 'Nigeria', 'Women -52 kg'),
#  ('Emmanuel Amunike', 'Uzbekistan', "Football Men's Football"),
#  ('KELDIYOROVA Diyora', 'Uzbekistan', "Football Men's Football"),
#  ('Emmanuel Amunike', 'Uzbekistan', 'Women -52 kg'),
#  ('KELDIYOROVA Diyora', 'Uzbekistan', 'Women -52 kg'),
#  ('Anja Jul Andersen', 'Denmark', "Handball Women's Handball"),
#  ('KINSELLA Alice', 'Denmark', "Handball Women's Handball"),
#  ('Anja Jul Andersen', 'Denmark', "Women's Balance Beam"),
#  ('KINSELLA Alice', 'Denmark', "Women's Balance Beam"),
#  ('Anja Jul Andersen', 'Great Britain', "Handball Women's Handball"),
#  ('KINSELLA Alice', 'Great Britain', "Handball Women's Handball"),
#  ('Anja Jul Andersen', 'Great Britain', "Women's Balance Beam"),
#  ('KINSELLA Alice', 'Great Britain', "Women's Balance Beam"),
#  ('Camilla Rseler Andersen', 'Denmark', "Handball Women's Handball"),
#  ('KIPYEGON Faith', 'Denmark', "Handball Women's Handball"),
#  ('Camilla Rseler Andersen', 'Denmark', "Women's 1500m"),
#  ('KIPYEGON Faith', 'Denmark', "Women's 1500m"),
#  ('Camilla Rseler Andersen', 'Kenya', "Handball Women's Handball"),
#  ('KIPYEGON Faith', 'Kenya', "Handball Women's Handball"),
#  ('Camilla Rseler Andersen', 'Kenya', "Women's 1500m"),
#  ('KIPYEGON Faith', 'Kenya', "Women's 1500m"),
#  ('Agneta Monica Andersson', 'Sweden', "Canoeing Women's Kayak Doubles, 500 metres"),
#  ('KOVALOV Stanislav', 'Sweden', "Canoeing Women's Kayak Doubles, 500 metres"),
#  ('Agneta Monica Andersson', 'Sweden', "Lightweight Men's Double Sculls Team"),
#  ('KOVALOV Stanislav', 'Sweden', "Lightweight Men's Double Sculls Team"),
#  ('Agneta Monica Andersson', 'Ukraine', "Canoeing Women's Kayak Doubles, 500 metres"),
#  ('KOVALOV Stanislav', 'Ukraine', "Canoeing Women's Kayak Doubles, 500 metres"),
#  ('Agneta Monica Andersson', 'Ukraine', "Lightweight Men's Double Sculls Team"),
#  ('KOVALOV Stanislav', 'Ukraine', "Lightweight Men's Double Sculls Team"),
#  ('LEOTLELA Gift', 'Australia', "Hockey Women's Hockey"),
#  ('Michelle "Shelley" Andrews (-Mitchell)', 'Australia', "Hockey Women's Hockey"),
#  ('LEOTLELA Gift', 'Australia', "Men's 100m"),
#  ('Michelle "Shelley" Andrews (-Mitchell)', 'Australia', "Men's 100m"),
#  ('LEOTLELA Gift', 'South Africa', "Hockey Women's Hockey"),
#  ('Michelle "Shelley" Andrews (-Mitchell)', 'South Africa', "Hockey Women's Hockey"),
#  ('LEOTLELA Gift', 'South Africa', "Men's 100m"),
#  ('Michelle "Shelley" Andrews (-Mitchell)', 'South Africa', "Men's 100m"),
#  ('Kurt Steven Angle', 'United States', 'Men -60 kg'),
#  ('LUTFILLAEV Sharafuddin', 'United States', 'Men -60 kg'),
#  ('Kurt Steven Angle', 'United States', "Wrestling Men's Heavyweight, Freestyle"),
#  ('LUTFILLAEV Sharafuddin', 'United States', "Wrestling Men's Heavyweight, Freestyle"),
#  ('Kurt Steven Angle', 'Uzbekistan', 'Men -60 kg'),
#  ('LUTFILLAEV Sharafuddin', 'Uzbekistan', 'Men -60 kg'),
#  ('Kurt Steven Angle', 'Uzbekistan', "Wrestling Men's Heavyweight, Freestyle"),
#  ('LUTFILLAEV Sharafuddin', 'Uzbekistan', "Wrestling Men's Heavyweight, Freestyle"),
#  ('Alyson Regina Annan', 'Australia', "Hockey Women's Hockey"),
#  ('MAILEY Madison', 'Australia', "Hockey Women's Hockey"),
#  ('Alyson Regina Annan', 'Australia', "Women's Eight Team"),
#  ('MAILEY Madison', 'Australia', "Women's Eight Team"),
#  ('Alyson Regina Annan', 'Canada', "Hockey Women's Hockey"),
#  ('MAILEY Madison', 'Canada', "Hockey Women's Hockey"),
#  ('Alyson Regina Annan', 'Canada', "Women's Eight Team"),
#  ('MAILEY Madison', 'Canada', "Women's Eight Team"),
#  ('Heidi Astrup', 'Denmark', "Handball Women's Handball"),
#  ('PIKULIK Daria', 'Denmark', "Handball Women's Handball"),
#  ('Heidi Astrup', 'Denmark', "Women's Madison Team"),
#  ('PIKULIK Daria', 'Denmark', "Women's Madison Team"),
#  ('Heidi Astrup', 'Poland', "Handball Women's Handball"),
#  ('PIKULIK Daria', 'Poland', "Handball Women's Handball"),
#  ('Heidi Astrup', 'Poland', "Women's Madison Team"),
#  ('PIKULIK Daria', 'Poland', "Women's Madison Team"),
#  ('Charles Allen Austin', 'Austria', "Athletics Men's High Jump"),
#  ('REITSHAMMER Bernhard', 'Austria', "Athletics Men's High Jump"),
#  ('Charles Allen Austin', 'Austria', "Men's 100m Backstroke"),
#  ('REITSHAMMER Bernhard', 'Austria', "Men's 100m Backstroke"),
#  ('Charles Allen Austin', 'United States', "Athletics Men's High Jump"),
#  ('REITSHAMMER Bernhard', 'United States', "Athletics Men's High Jump"),
#  ('Charles Allen Austin', 'United States', "Men's 100m Backstroke"),
#  ('REITSHAMMER Bernhard', 'United States', "Men's 100m Backstroke"),
#  ('Filiberto Azcuy Aguilera', 'Cuba', 'Eventing Team'),
#  ('SAMRAN Korntawat', 'Cuba', 'Eventing Team'),
#  ('Filiberto Azcuy Aguilera', 'Cuba', "Wrestling Men's Welterweight, Greco-Roman"),
#  ('SAMRAN Korntawat', 'Cuba', "Wrestling Men's Welterweight, Greco-Roman"),
#  ('Filiberto Azcuy Aguilera', 'Thailand', 'Eventing Team'),
#  ('SAMRAN Korntawat', 'Thailand', 'Eventing Team'),
#  ('Filiberto Azcuy Aguilera', 'Thailand', "Wrestling Men's Welterweight, Greco-Roman"),
#  ('SAMRAN Korntawat', 'Thailand', "Wrestling Men's Welterweight, Greco-Roman"),
#  ('Jennifer Lynn Azzi', 'Poland', "Basketball Women's Basketball"),
#  ('SARNECKI Rafal', 'Poland', "Basketball Women's Basketball"),
#  ('Jennifer Lynn Azzi', 'Poland', "Men's Team Sprint Team"),
#  ('SARNECKI Rafal', 'Poland', "Men's Team Sprint Team"),
#  ('Jennifer Lynn Azzi', 'United States', "Basketball Women's Basketball"),
#  ('SARNECKI Rafal', 'United States', "Basketball Women's Basketball"),
#  ('Jennifer Lynn Azzi', 'United States', "Men's Team Sprint Team"),
#  ('SARNECKI Rafal', 'United States', "Men's Team Sprint Team"),
#  ('SCHAEFER-BETZ Pauline', 'Germany', "Football Men's Football"),
#  ('Tijani Babangida', 'Germany', "Football Men's Football"),
#  ('SCHAEFER-BETZ Pauline', 'Germany', "Women's Team"),
#  ('Tijani Babangida', 'Germany', "Women's Team"),
#  ('SCHAEFER-BETZ Pauline', 'Nigeria', "Football Men's Football"),
#  ('Tijani Babangida', 'Nigeria', "Football Men's Football"),
#  ('SCHAEFER-BETZ Pauline', 'Nigeria', "Women's Team"),
#  ('Tijani Babangida', 'Nigeria', "Women's Team"),
#  ('Celestine Boyd Jonto Hycieth Babayaro', 'Nigeria', "Football Men's Football"),
#  ('SCHIR Thery', 'Nigeria', "Football Men's Football"),
#  ('Celestine Boyd Jonto Hycieth Babayaro', 'Nigeria', "Men's Omnium"),
#  ('SCHIR Thery', 'Nigeria', "Men's Omnium"),
#  ('Celestine Boyd Jonto Hycieth Babayaro', 'Switzerland', "Football Men's Football"),
#  ('SCHIR Thery', 'Switzerland', "Football Men's Football"),
#  ('Celestine Boyd Jonto Hycieth Babayaro', 'Switzerland', "Men's Omnium"),
#  ('SCHIR Thery', 'Switzerland', "Men's Omnium"),
#  ('Donovan Bailey', 'Brazil', "Athletics Men's 100 metres"),
#  ('STEVAUX CARNAVAL Priscilla Andreia', 'Brazil', "Athletics Men's 100 metres"),
#  ('Donovan Bailey', 'Brazil', 'Women'),
#  ('STEVAUX CARNAVAL Priscilla Andreia', 'Brazil', 'Women'),
#  ('Donovan Bailey', 'Canada', "Athletics Men's 100 metres"),
#  ('STEVAUX CARNAVAL Priscilla Andreia', 'Canada', "Athletics Men's 100 metres"),
#  ('Donovan Bailey', 'Canada', 'Women'),
#  ('STEVAUX CARNAVAL Priscilla Andreia', 'Canada', 'Women'),
#  ('Donovan Bailey', 'Australia', "Athletics Men's 4 x 100 metres Relay"),
#  ('STEVENS Dani', 'Australia', "Athletics Men's 4 x 100 metres Relay"),
#  ('Donovan Bailey', 'Australia', "Women's Discus Throw"),
#  ('STEVENS Dani', 'Australia', "Women's Discus Throw"),
#  ('Donovan Bailey', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('STEVENS Dani', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('Donovan Bailey', 'Canada', "Women's Discus Throw"),
#  ('STEVENS Dani', 'Canada', "Women's Discus Throw"),
#  ('Marta Bald Marn', 'Japan', 'Eventing Individual'),
#  ('TOMOTO Kazuma', 'Japan', 'Eventing Individual'),
#  ('Marta Bald Marn', 'Japan', "Rhythmic Gymnastics Women's Group"),
#  ('TOMOTO Kazuma', 'Japan', "Rhythmic Gymnastics Women's Group"),
#  ('Marta Bald Marn', 'Spain', 'Eventing Individual'),
#  ('TOMOTO Kazuma', 'Spain', 'Eventing Individual'),
#  ('Marta Bald Marn', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('TOMOTO Kazuma', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Nikolaus "Klaus" Balkenhol', 'Germany', 'Equestrianism Mixed Dressage, Team'),
#  ('TRATNIK Jan', 'Germany', 'Equestrianism Mixed Dressage, Team'),
#  ('Nikolaus "Klaus" Balkenhol', 'Germany', "Men's Road Race"),
#  ('TRATNIK Jan', 'Germany', "Men's Road Race"),
#  ('Nikolaus "Klaus" Balkenhol', 'Slovenia', 'Equestrianism Mixed Dressage, Team'),
#  ('TRATNIK Jan', 'Slovenia', 'Equestrianism Mixed Dressage, Team'),
#  ('Nikolaus "Klaus" Balkenhol', 'Slovenia', "Men's Road Race"),
#  ('TRATNIK Jan', 'Slovenia', "Men's Road Race"),
#  ('Flicia Michele Sylviane Ballanger (-Vetu)', 'Belarus', "Cycling Women's Sprint"),
#  ('TSURKIN Yauhen', 'Belarus', "Cycling Women's Sprint"),
#  ('Flicia Michele Sylviane Ballanger (-Vetu)', 'Belarus', "Men's 100m Butterfly"),
#  ('TSURKIN Yauhen', 'Belarus', "Men's 100m Butterfly"),
#  ('Flicia Michele Sylviane Ballanger (-Vetu)', 'France', "Cycling Women's Sprint"),
#  ('TSURKIN Yauhen', 'France', "Cycling Women's Sprint"),
#  ('Flicia Michele Sylviane Ballanger (-Vetu)', 'France', "Men's 100m Butterfly"),
#  ('TSURKIN Yauhen', 'France', "Men's 100m Butterfly"),
#  ('Daniel Ballart Sans', 'Spain', "Water Polo Men's Water Polo"),
#  ('TULIAMUK Aliphine Chepkerker', 'Spain', "Water Polo Men's Water Polo"),
#  ('Daniel Ballart Sans', 'Spain', "Women's Marathon"),
#  ('TULIAMUK Aliphine Chepkerker', 'Spain', "Women's Marathon"),
#  ('Daniel Ballart Sans', 'United States', "Water Polo Men's Water Polo"),
#  ('TULIAMUK Aliphine Chepkerker', 'United States', "Water Polo Men's Water Polo"),
#  ('Daniel Ballart Sans', 'United States', "Women's Marathon"),
#  ('TULIAMUK Aliphine Chepkerker', 'United States', "Women's Marathon"),
#  ('Jos Luis Ballester Tuliesa', 'Spain', 'Sailing Mixed Multihull'),
#  ('TURSUNKULOVA Nigora', 'Spain', 'Sailing Mixed Multihull'),
#  ('Jos Luis Ballester Tuliesa', 'Spain', 'Women -67kg'),
#  ('TURSUNKULOVA Nigora', 'Spain', 'Women -67kg'),
#  ('Jos Luis Ballester Tuliesa', 'Uzbekistan', 'Sailing Mixed Multihull'),
#  ('TURSUNKULOVA Nigora', 'Uzbekistan', 'Sailing Mixed Multihull'),
#  ('Jos Luis Ballester Tuliesa', 'Uzbekistan', 'Women -67kg'),
#  ('TURSUNKULOVA Nigora', 'Uzbekistan', 'Women -67kg'),
#  ('Bang Su-Hyeon', 'Cuba', "Badminton Women's Singles"),
#  ('VELAZCO Davisleydi', 'Cuba', "Badminton Women's Singles"),
#  ('Bang Su-Hyeon', 'Cuba', "Women's Triple Jump"),
#  ('VELAZCO Davisleydi', 'Cuba', "Women's Triple Jump"),
#  ('Bang Su-Hyeon', 'South Korea', "Badminton Women's Singles"),
#  ('VELAZCO Davisleydi', 'South Korea', "Badminton Women's Singles"),
#  ('Bang Su-Hyeon', 'South Korea', "Women's Triple Jump"),
#  ('VELAZCO Davisleydi', 'South Korea', "Women's Triple Jump"),
#  ('Charles Wade Barkley', 'Japan', "Basketball Men's Basketball"),
#  ('YAMAGUCHI Kosei', 'Japan', "Basketball Men's Basketball"),
#  ('Charles Wade Barkley', 'Japan', "Men's 3000m Steeplechase"),
#  ('YAMAGUCHI Kosei', 'Japan', "Men's 3000m Steeplechase"),
#  ('Charles Wade Barkley', 'United States', "Basketball Men's Basketball"),
#  ('YAMAGUCHI Kosei', 'United States', "Basketball Men's Basketball"),
#  ('Charles Wade Barkley', 'United States', "Men's 3000m Steeplechase"),
#  ('YAMAGUCHI Kosei', 'United States', "Men's 3000m Steeplechase"),
#  ('Valrie Gisele Angele Barlois-Mevel-Leroux', 'France', "Fencing Women's epee, Team"),
#  ('YANAGISAWA Akane', 'France', "Fencing Women's epee, Team"),
#  ('Valrie Gisele Angele Barlois-Mevel-Leroux', 'France', 'Team'),
#  ('YANAGISAWA Akane', 'France', 'Team'),
#  ('Valrie Gisele Angele Barlois-Mevel-Leroux', 'Japan', "Fencing Women's epee, Team"),
#  ('YANAGISAWA Akane', 'Japan', "Fencing Women's epee, Team"),
#  ('Valrie Gisele Angele Barlois-Mevel-Leroux', 'Japan', 'Team'),
#  ('YANAGISAWA Akane', 'Japan', 'Team'),
#  ('Eric Randolph "Randy" Barnes', 'Kazakhstan', "Athletics Men's Shot Put"),
#  ('YEMELYANOV Sergey', 'Kazakhstan', "Athletics Men's Shot Put"),
#  ('Eric Randolph "Randy" Barnes', 'Kazakhstan', "Men's Canoe Double 1000m Team"),
#  ('YEMELYANOV Sergey', 'Kazakhstan', "Men's Canoe Double 1000m Team"),
#  ('Eric Randolph "Randy" Barnes', 'United States', "Athletics Men's Shot Put"),
#  ('YEMELYANOV Sergey', 'United States', "Athletics Men's Shot Put"),
#  ('Eric Randolph "Randy" Barnes', 'United States', "Men's Canoe Double 1000m Team"),
#  ('YEMELYANOV Sergey', 'United States', "Men's Canoe Double 1000m Team"),
#  ('Michiel Bernhard Emiel Marie Bartman', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Amanda Ray Beard (-Brown)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Ludger Beerbaum', 'Germany', 'Equestrianism Mixed Jumping, Team'),
#  ('Aleksandr Vladimirovich Beketov', 'Russia', "Fencing Men's epee, Individual"),
#  ('Regla Maritza Bell McKenzie', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Antonella Bellutti', 'Italy', "Cycling Women's Individual Pursuit, 3,000 metres"),
#  ('Brooke Marie Bennett (-Frioud)', 'United States', "Swimming Women's 800 metres Freestyle"),
#  ('Laura Kay Berg', 'United States', "Softball Women's Softball"),
#  ('Ryan Thomas Berube', 'United States', "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  ('Suzannah Bianco', 'United States', "Synchronized Swimming Women's Team"),
#  ('Peter Blang', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Kay Bluhm', 'Germany', "Canoeing Men's Kayak Doubles, 500 metres"),
#  ('Vadim Iosifovich Bogiyev', 'Russia', "Wrestling Men's Lightweight, Freestyle"),
#  ('Alice Ruth "Ruthie" Bolton-Holifield', 'United States', "Basketball Women's Basketball"),
#  ('Amanda Kathleen Borden (-Cochran)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Kathrin Boron (-Kppen)', 'Germany', "Rowing Women's Quadruple Sculls"),
#  ('Francesca Bortolozzi-Borella', 'Italy', "Fencing Women's Foil, Team"),
#  ('Elizabeth Anne "Beth" Botsford', 'United States', "Swimming Women's 100 metres Backstroke"),
#  ('Elizabeth Anne "Beth" Botsford', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Djamel Bouras', 'France', "Judo Men's Half-Middleweight"),
#  ('Floris Jan Bovelander', 'Netherlands', "Hockey Men's Hockey"),
#  ('Gillian Dewey Boxx', 'United States', "Softball Women's Softball"),
#  ('Daniel Bozhinov Petrov', 'Bulgaria', "Boxing Men's Light-Flyweight"),
#  ('Tina Nielsen Bttzau (-Haunstrup)', 'Denmark', "Handball Women's Handball"),
#  ('Thomas Nelson "Tom" Brands, II', 'United States', "Wrestling Men's Featherweight, Freestyle"),
#  ('Yevhen Anatoliyovych Braslavets', 'Ukraine', "Sailing Men's Two Person Dinghy"),
#  ('Bart Jan-Baptist Marie Brentjens', 'Netherlands', "Cycling Men's Mountainbike, Cross-Country"),
#  ('Bradley Michael "Brad" Bridgewater', 'United States', "Swimming Men's 200 metres Backstroke"),
#  ('Jacques Brinkman', 'Netherlands', "Hockey Men's Hockey"),
#  ('Anja Byrial Hansen (-Pedersen)', 'Denmark', "Handball Women's Handball"),
#  ('Nuria Cabanillas Provencio', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Miguel Calds Luis', 'Cuba', "Baseball Men's Baseball"),
#  ('Christophe Capelle', 'France', "Cycling Men's Team Pursuit, 4,000 metres"),
#  ('Laura Gabriela Crlescu-Badea', 'Romania', "Fencing Women's Foil, Individual"),
#  ('Magalys Esther Carvajal Rivera', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Patrik avar', 'Croatia', "Handball Men's Handball"),
#  ('Carlton Chambers', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('Brandi Denise Chastain', 'United States', "Football Women's Football"),
#  ('Jury Dimitri Chechi', 'Italy', "Gymnastics Men's Rings"),
#  ('Andrey Ivanovich Chemerkin', 'Russia', "Weightlifting Men's Super-Heavyweight"),
#  ('Amy Yuen-Yee Chow (-Ho)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Tammy P. Cleland-McGregor', 'United States', "Synchronized Swimming Women's Team"),
#  ('Veronica Cogeanu-Cochela', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Andrea Collinelli', 'Italy', "Cycling Men's Individual Pursuit, 4,000 metres"),
#  ('Jos Ariel Contreras Camejo', 'Cuba', "Baseball Men's Baseball"),
#  ('Sheila Marie Cornell-Douty', 'United States', "Softball Women's Softball"),
#  ('Marlenis Costa Blanco', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Kendall Duane Cross', 'United States', "Wrestling Men's Bantamweight, Freestyle"),
#  ('Maurits Bourgon Crucq', 'Netherlands', "Hockey Men's Hockey"),
#  ('Sandro Cuomo', 'Italy', "Fencing Men's epee, Team"),
#  ('Attila Czene', 'Hungary', "Swimming Men's 200 metres Individual Medley"),
#  ('Lindsay Ann Davenport', 'United States', "Tennis Women's Singles"),
#  ('Joshua Clark "Josh" Davis', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Joshua Clark "Josh" Davis', 'United States', "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  ('Joshua Clark "Josh" Davis', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Dominique Margaux Dawes (-Thompson)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Teun Floris de Nooijer', 'Netherlands', "Hockey Men's Hockey"),
#  ('Frdrik Edouard Robert "Fred" Deburghgraeve', 'Belgium', "Swimming Men's 100 metres Breaststroke"),
#  ('Marcus Johannes Elizabeth Leopold "Marc" Delissen', 'Netherlands', "Hockey Men's Hockey"),
#  ('Jeroen Petrus Maria Delme', 'Netherlands', "Hockey Men's Hockey"),
#  ('Mahmut Demir', 'Turkey', "Wrestling Men's Super-Heavyweight, Freestyle"),
#  ('Deng Yaping', 'China', "Table Tennis Women's Singles"),
#  ('Deng Yaping', 'China-1', "Table Tennis Women's Doubles"),
#  ('Yolanda Gail L. Devers (-Roberts)', 'United States', "Athletics Women's 100 metres"),
#  ('Yolanda Gail L. Devers (-Roberts)', 'United States', "Athletics Women's 4 x 100 metres Relay"),
#  ('Roberto Di Donna', 'Italy', "Shooting Men's Air Pistol, 10 metres"),
#  ('Michael Constantine Diamond (Diamondopoulous-)', 'Australia', "Shooting Men's Trap"),
#  ('Pyrros Dimas', 'Greece', "Weightlifting Men's Light-Heavyweight"),
#  ('Andreas Dittmer', 'Germany', "Canoeing Men's Canadian Doubles, 1,000 metres"),
#  ('Louise Karen Dobson', 'Australia', "Hockey Women's Hockey"),
#  ('Martin Doktor', 'Czech Republic', "Canoeing Men's Canadian Singles, 500 metres"),
#  ('Martin Doktor', 'Czech Republic', "Canoeing Men's Canadian Singles, 1,000 metres"),
#  ('Thomas Fitzgerald "Tom" Dolan', 'United States', "Swimming Men's 400 metres Individual Medley"),
#  ('Joseph Dosu (Oladosu-)', 'Nigeria', "Football Men's Football"),
#  ('David Douillet', 'France', "Judo Men's Heavyweight"),
#  ('Phillip Peter Dutton', 'Australia', 'Equestrianism Mixed Three-Day Event, Team'),
#  ('Jeroen Tarquinis Cornelis Duyster', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Rebekah "Becky" Dyroen-Lancer', 'United States', "Synchronized Swimming Women's Team"),
#  ('Eskild Balschmidt Ebbesen', 'Denmark', "Rowing Men's Lightweight Coxless Fours"),
#  ('Teresa Edwards', 'United States', "Basketball Women's Basketball"),
#  ('Krisztina Egerszegi', 'Hungary', "Swimming Women's 200 metres Backstroke"),
#  ('Yuko Emoto', 'Japan', "Judo Women's Half-Middleweight"),
#  ('Philippe Ermenault', 'France', "Cycling Men's Team Pursuit, 4,000 metres"),
#  ('Robert Esmie', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('Manuel Estiarte Duocastella', 'Spain', "Water Polo Men's Water Polo"),
#  ('Jos Antonio Estrada Gonzlez', 'Cuba', "Baseball Men's Baseball"),
#  ('Nathalie Even-Lancien', 'France', "Cycling Women's Points Race"),
#  ('Ennio Falco', 'Italy', "Shooting Men's Skeet"),
#  ('Renita Maree Farrell-Garard', 'Australia', "Hockey Women's Hockey"),
#  ('Teslim Babatunde Fatusi', 'Nigeria', "Football Men's Football"),
#  ('Joy Lynn Fawcett (Biefeld-)', 'United States', "Football Women's Football"),
#  ('Victor Alexander Feddersen', 'Denmark', "Rowing Men's Lightweight Coxless Fours"),
#  ('Ana Ivis Fernndez Valle', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Beatriz Cristina "Gigi" Fernandez', 'United States', "Tennis Women's Doubles"),
#  ('Lisa M. Fernandez (-Lujan)', 'United States', "Softball Women's Softball"),
#  ('Maria Jose "Mary Joe" Fernandez (-Godsick)', 'United States', "Tennis Women's Doubles"),
#  ('Marcelo Bastos Ferreira', 'Brazil', 'Sailing Mixed Two Person Keelboat'),
#  ('Jens Fiedler', 'Germany', "Cycling Men's Sprint"),
#  ('Birgit Fischer-Schmidt', 'Germany', "Canoeing Women's Kayak Fours, 500 metres"),
#  ('Oliver Fix', 'Germany', "Canoeing Men's Kayak Singles, Slalom"),
#  ('Thomas Flach', 'Germany', 'Sailing Mixed Three Person Keelboat'),
#  ('Laura lodie Flessel-Colovic', 'France', "Fencing Women's epee, Individual"),
#  ('Laura lodie Flessel-Colovic', 'France', "Fencing Women's epee, Team"),
#  ('Ronald Florijn', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Marianne Florman Christensen', 'Denmark', "Handball Women's Handball"),
#  ('Wilfrid Forgues', 'France-1', "Canoeing Men's Canadian Doubles, Slalom"),
#  ('Julie Maurine Foudy', 'United States', "Football Women's Football"),
#  ('Catherine Mai-Lan Fox', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Catherine Mai-Lan Fox', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('David Ashley Fox', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Valner Frankovi', 'Croatia', "Handball Men's Handball"),
#  ('Fu Mingxia', 'China', "Diving Women's Springboard"),
#  ('Fu Mingxia', 'China', "Diving Women's Platform"),
#  ('Jorge Francisco Fumero Fernndez', 'Cuba', "Baseball Men's Baseball"),
#  ('Carin Leslie Gabarra (Jennings-)', 'United States', "Football Women's Football"),
#  ('Liliana Gafencu', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Chryste Dionne Gaines', 'United States', "Athletics Women's 4 x 100 metres Relay"),
#  ('Jean Galfione', 'France', "Athletics Men's Pole Vault"),
#  ('Pedro Francisco Garca Aguado', 'Spain', "Water Polo Men's Water Polo"),
#  ('Idalmis Gato Moya', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Ge Fei', 'China-2', "Badminton Women's Doubles"),
#  ('Haile Gebrselassie', 'Ethiopia', "Athletics Men's 10,000 metres"),
#  ('Elena Georgescu-Nedelcu', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Markus Gier', 'Switzerland', "Rowing Men's Lightweight Double Sculls"),
#  ('Michael Gier', 'Switzerland', "Rowing Men's Lightweight Double Sculls"),
#  ('Glenroy John Gilbert', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('Estela Gimnez Cid', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Drew Cameron Ginn', 'Australia', "Rowing Men's Coxless Fours"),
#  ('Gir Yeong-A', 'South Korea-1', 'Badminton Mixed Doubles'),
#  ('Slavko Golua', 'Croatia', "Handball Men's Handball"),
#  ('Salvador Emilio Gmez Agera', 'Spain', "Water Polo Men's Water Polo"),
#  ('Driulys Gonzlez Morales', 'Cuba', "Judo Women's Lightweight"),
#  ('Guido Grtzen', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Robert Karl Baldwin "Rob" Grabert', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Torben Schmidt Grael', 'Brazil', 'Sailing Mixed Two Person Keelboat'),
#  ('Kimberly Elaine "Kim" Graham (-Miller)', 'United States', "Athletics Women's 4 x 400 metres Relay"),
#  ('Michele M. Granger', 'United States', "Softball Women's Softball"),
#  ('Nicholas David "Nick" Green', 'Australia', "Rowing Men's Coxless Fours"),
#  ('Kurt David Grote', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Gu Jun', 'China-2', "Badminton Women's Doubles"),
#  ('Bruno Gudelj', 'Croatia', "Handball Men's Handball"),
#  ('Carlette Denise Guidry-White (-Falkquay)', 'United States', "Athletics Women's 4 x 100 metres Relay"),
#  ('Lorena Gurndez Garca', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Torsten Ren Gutsche', 'Germany', "Canoeing Men's Kayak Doubles, 500 metres"),
#  ('Andreas Hajek', 'Germany', "Rowing Men's Quadruple Sculls"),
#  ('Gary Wayne Hall, Jr.', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Gary Wayne Hall, Jr.', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Conny Hamann-Boeriths', 'Denmark', "Handball Women's Handball"),
#  ('Mariel Margaret "Mia" Hamm (-Corry, -Garciaparra)', 'United States', "Football Women's Football"),
#  ('Anfernee Deon "Penny" Hardaway', 'United States', "Basketball Men's Basketball"),
#  ('John Lawson Hargis', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Lori D. Harrigan (-Mack)', 'United States', "Softball Women's Softball"),
#  ('Dionna Marie Harris', 'United States', "Softball Women's Softball"),
#  ('Alvin Leonardo Harrison', 'United States', "Athletics Men's 4 x 400 metres Relay"),
#  ('Kerry Lorenzo "Kenny" Harrison', 'United States', "Athletics Men's Triple Jump"),
#  ('Juliet Haslam', 'Australia', "Hockey Women's Hockey"),
#  ('Rechelle Margaret Hawkes', 'Australia', "Hockey Women's Hockey"),
#  ('Kathleen Joan Heddle', 'Canada', "Rowing Women's Double Sculls"),
#  ('Whitney Lynn Hedgepeth (-Luther)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Hendrik Jan "Henk Jan" Held', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Deon Marie Hemmings', 'Jamaica', "Athletics Women's 400 metres Hurdles"),
#  ('Mark Andrew Henderson', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Niels Laulund Henriksen', 'Denmark', "Rowing Men's Lightweight Coxless Fours"),
#  ('Jos Alberto Hernndez Prez', 'Cuba', "Baseball Men's Baseball"),
#  ('Ariel Hernndez Azcuy', 'Cuba', "Boxing Men's Middleweight"),
#  ('Penelope "Penny" Heyns', 'South Africa', "Swimming Women's 100 metres Breaststroke"),
#  ('Penelope "Penny" Heyns', 'South Africa', "Swimming Women's 200 metres Breaststroke"),
#  ('tpnka Hilgertov (Prokov-)', 'Czech Republic', "Canoeing Women's Kayak Singles, Slalom"),
#  ('Grant Henry Hill', 'United States', "Basketball Men's Basketball"),
#  ('Anette Hoffmann-Mberg', 'Denmark', "Handball Women's Handball"),
#  ('Detlef Hofmann', 'Germany', "Canoeing Men's Kayak Fours, 1,000 metres"),
#  ('Knut Holmann', 'Norway', "Canoeing Men's Kayak Singles, 1,000 metres"),
#  ('Csaba Horvth', 'Hungary', "Canoeing Men's Canadian Doubles, 500 metres"),
#  ('Andrew James Hoy', 'Australia', 'Equestrianism Mixed Three-Day Event, Team'),
#  ('Poul-Erik Hyer Larsen (-Engel Hyer)', 'Denmark', "Badminton Men's Singles"),
#  ('Joseph Bernard "Joe" Hudepohl', 'United States', "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  ('Justin Grant Huish', 'United States', "Archery Men's Individual"),
#  ('Justin Grant Huish', 'United States', "Archery Men's Team"),
#  ('Doina Ignat', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Victor Nosa Ikpeba', 'Nigeria', "Football Men's Football"),
#  ('Miguel ngel Indurin Larraya', 'Spain', "Cycling Men's Individual Time Trial"),
#  ('Rey Isaac Vaillant', 'Cuba', "Baseball Men's Baseball"),
#  ('Aleksandra Ivoev', 'Serbia and Montenegro', "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres"),
#  ('Lilia Izquierdo Aguirre', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Trina Marie Jackson (-Falca)', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Lisa Rae Jacob', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Lisa Rae Jacob', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Bernd Jkel', 'Germany', 'Sailing Mixed Three Person Keelboat'),
#  ('Franciscus Ronaldus Maria "Ronald" Jansen', 'Netherlands', "Hockey Men's Hockey"),
#  ('Erik Alexander Jazet', 'Netherlands', "Hockey Men's Hockey"),
#  ('Vladimir Jeli', 'Croatia', "Handball Men's Handball"),
#  ('Jeon Gi-Yeong', 'South Korea', "Judo Men's Middleweight"),
#  ('Jo Min-Seon', 'South Korea', "Judo Women's Middleweight"),
#  ('Allen Kenneth Johnson', 'United States', "Athletics Men's 110 metres Hurdles"),
#  ('Richard Andrew "Butch" Johnson', 'United States', "Archery Men's Team"),
#  ('Michael Duane Johnson', 'United States', "Athletics Men's 200 metres"),
#  ('Michael Duane Johnson', 'United States', "Athletics Men's 400 metres"),
#  ('Boidar Jovi', 'Croatia', "Handball Men's Handball"),
#  ('Akakios Kakiasvili', 'Greece', "Weightlifting Men's Heavyweight I"),
#  ('Nikolaos "Nikos" Kaklamanakis', 'Greece', "Sailing Men's Windsurfer"),
#  ('Somluck Kamsing', 'Thailand', "Boxing Men's Featherweight"),
#  ('Nwankwo Christian Nwosu Kanu', 'Nigeria', "Football Men's Football"),
#  ('Aleksandr Aleksandrovich Karelin', 'Russia', "Wrestling Men's Super-Heavyweight, Greco-Roman"),
#  ('Joseph Keter', 'Kenya', "Athletics Men's 3,000 metres Steeplechase"),
#  ('Rasoul Khadem Azgadhi', 'Iran', "Wrestling Men's Light-Heavyweight, Freestyle"),
#  ('Artyom Aleksandrovich Khadzhibekov', 'Russia', "Shooting Men's Air Rifle, 10 metres"),
#  ('Sergey Vladimirovich Kharkov', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Yekaterina Anatolyevna Khodotovich-Karsten', 'Belarus', "Rowing Women's Single Sculls"),
#  ('Svetlana Vasilyevna Khorkina', 'Russia', "Gymnastics Women's Uneven Bars"),
#  ('Kim Dong-Mun', 'South Korea-1', 'Badminton Mixed Doubles'),
#  ('Kim Gyeong-Uk', 'South Korea', "Archery Women's Individual"),
#  ('Kim Gyeong-Uk', 'South Korea', "Archery Women's Team"),
#  ('Kim Il-Ong', 'North Korea', "Wrestling Men's Light-Flyweight, Freestyle"),
#  ('Kim Jo-Sun', 'South Korea', "Archery Women's Team"),
#  ('Orestes Kindeln Olivares', 'Cuba', "Baseball Men's Baseball"),
#  ('Charles Frederick "Karch" Kiraly', 'United States-1', "Beach Volleyball Men's Beach Volleyball"),
#  ('Gunar Kirchbach', 'Germany', "Canoeing Men's Canadian Doubles, 1,000 metres"),
#  ('Ulrich Gnter Hermann "Uli" Kirchhoff', 'Germany', 'Equestrianism Mixed Jumping, Individual'),
#  ('Ulrich Gnter Hermann "Uli" Kirchhoff', 'Germany', 'Equestrianism Mixed Jumping, Team'),
#  ('Grigory Anatolyevich Kiriyenko', 'Russia', "Fencing Men's Sabre, Team"),
#  ('Balzs Kiss', 'Hungary', "Athletics Men's Hammer Throw"),
#  ('Tonje Kjrgaard (-Petersen)', 'Denmark', "Handball Women's Handball"),
#  ('Christian Klees', 'Germany', "Shooting Men's Small-Bore Rifle, Prone, 50 metres"),
#  ('Leo Klein Gebbink', 'Netherlands', "Hockey Men's Hockey"),
#  ('Volodymyr Volodymyrovych Klychko', 'Ukraine', "Boxing Men's Super-Heavyweight"),
#  ('Nenad Kljai', 'Croatia', "Handball Men's Handball"),
#  ('Olga Gennadyevna Klochneva-Kuznetsova', 'Russia', "Shooting Women's Air Pistol, 10 metres"),
#  ('Rita Kbn', 'Hungary', "Canoeing Women's Kayak Singles, 500 metres"),
#  ('Boris Borisovich Kokorev', 'Russia', "Shooting Men's Free Pistol, 50 metres"),
#  ('Janne Kolling (-Johannesen)', 'Denmark', "Handball Women's Handball"),
#  ('Gyrgy Kolonics', 'Hungary', "Canoeing Men's Canadian Doubles, 500 metres"),
#  ('Kong Linghui', 'China-2', "Table Tennis Men's Doubles"),
#  ('Kerstin Kppen (Kosbab-)', 'Germany', "Rowing Women's Quadruple Sculls"),
#  ('Robert Marek Korzeniowski', 'Poland', "Athletics Men's 50 kilometres Walk"),
#  ('Stefka Georgieva Kostadinova (-Petrova, -Popovasileva)', 'Bulgaria', "Athletics Women's High Jump"),
#  ('Istvn Kovcs', 'Hungary', "Boxing Men's Bantamweight"),
#  ('Inesa Mykolavna Kravets (Shuliak-, -Izvachuk)', 'Ukraine', "Athletics Women's Triple Jump"),
#  ('Nikolay Vyacheslavovich Kryukov', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Astrid Kumbernuss', 'Germany', "Athletics Women's Shot Put"),
#  ('Mateusz Kusznierewicz', 'Poland', "Sailing Men's One Person Dinghy"),
#  ('Kye Sun-Hui', 'North Korea', "Judo Women's Extra-Lightweight"),
#  ('Venus Milette Lacey', 'United States', "Basketball Women's Basketball"),
#  ('Tania Lamarca Celada', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Pablo Lara Rodrguez', 'Cuba', "Weightlifting Men's Middleweight"),
#  ('Misha Jonas Emanuel Latuhihin', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Susanne Munk Lauritsen (-Wilbek)', 'Denmark', "Handball Women's Handball"),
#  ('Garba Lawal', 'Nigeria', "Football Men's Football"),
#  ('Pedro Luis Lazo Iglesias', 'Cuba', "Baseball Men's Baseball"),
#  ('Le Jingyi', 'China', "Swimming Women's 100 metres Freestyle"),
#  ('Lee Lai Shan', 'Hong Kong', "Sailing Women's Windsurfer"),
#  ('Fernando Lon Boissier', 'Spain', 'Sailing Mixed Multihull'),
#  ('Lisa Deshawn Leslie (-Lockwood)', 'United States', "Basketball Women's Basketball"),
#  ('Emily LeSueur (Porter-)', 'United States', "Synchronized Swimming Women's Team"),
#  ('Frederick Carlton "Carl" Lewis', 'United States', "Athletics Men's Long Jump"),
#  ('Donghua Li', 'Switzerland', "Gymnastics Men's Pommelled Horse"),
#  ('Li Duihong', 'China', "Shooting Women's Sporting Pistol, 25 metres"),
#  ('Li Xiaoshuang', 'China', "Gymnastics Men's Individual All-Around"),
#  ('Kristine Marie Lilly (-Heavey)', 'United States', "Football Women's Football"),
#  ('Omar Linares Izquierdo', 'Cuba', "Baseball Men's Baseball"),
#  ('Jeremy Porter Linn', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Liu Guoliang', 'China', "Table Tennis Men's Singles"),
#  ('Liu Guoliang', 'China-2', "Table Tennis Men's Doubles"),
#  ('Danyon Joseph Loader', 'New Zealand', "Swimming Men's 200 metres Freestyle"),
#  ('Danyon Joseph Loader', 'New Zealand', "Swimming Men's 400 metres Freestyle"),
#  ('Rebecca Rose Lobo (-Rushin)', 'United States', "Basketball Women's Basketball"),
#  ('Abraham Robertus "Bram" Lomans', 'Netherlands', "Hockey Men's Hockey"),
#  ('Jeannie Longo-Ciprelli', 'France', "Cycling Women's Road Race, Individual"),
#  ('Venio Losert', 'Croatia', "Handball Men's Handball"),
#  ('Alejandrina Mireya Luis Hernndez', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Omar Luis Martnez', 'Cuba', "Baseball Men's Baseball"),
#  ('Jacob Arnold "Koos" Maasdijk', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Shannon Ann MacMillan', 'United States', "Football Women's Football"),
#  ('Camelia Macoviciuc-Mihalcea', 'Romania', "Rowing Women's Lightweight Double Sculls"),
#  ('Gitte Madsen', 'Denmark', "Handball Women's Handball"),
#  ('Khadzhimurat Saygidmagomedovich Magomedov', 'Russia', "Wrestling Men's Middleweight, Freestyle"),
#  ('Kim Ly Maher', 'United States', "Softball Women's Softball"),
#  ('Rexy Ronald Mainaky', 'Indonesia', "Badminton Men's Doubles"),
#  ('Clover Margaret Maitland', 'Australia', "Hockey Women's Hockey"),
#  ('Karl Malone', 'United States', "Basketball Men's Basketball"),
#  ('Maicel Donee Malone (-Wallace, -Trapp)', 'United States', "Athletics Women's 4 x 400 metres Relay"),
#  ('Ilgar Yashar-ogly Mamedov', 'Russia', "Fencing Men's Foil, Team"),
#  ('Juan Manrique Garca', 'Cuba', "Baseball Men's Baseball"),
#  ('Russell Andrew Mark', 'Australia', "Shooting Men's Double Trap"),
#  ('Karen Elizabeth Marsden', 'Australia', "Hockey Women's Hockey"),
#  ('Michal Martikn', 'Slovakia', "Canoeing Men's Canadian Singles, Slalom"),
#  ('Silvio Martinello', 'Italy', "Cycling Men's Points Race"),
#  ('Estbaliz Martnez Yerro', 'Spain', "Rhythmic Gymnastics Women's Group"),
#  ('Angelina L. "Angel" Martino (Myers-, -Sims)', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Angelina L. "Angel" Martino (Myers-, -Sims)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Svetlana Aleksandrovna Masterkova', 'Russia', "Athletics Women's 800 metres"),
#  ('Svetlana Aleksandrovna Masterkova', 'Russia', "Athletics Women's 1,500 metres"),
#  ('Valter Matoevi', 'Croatia', "Handball Men's Handball"),
#  ('Ihor Hryhorovych Matviyenko', 'Ukraine', "Sailing Men's Two Person Dinghy"),
#  ('Renata Magorzata Mauer-Raska', 'Poland', "Shooting Women's Air Rifle, 10 metres"),
#  ('Anthuan Maybank', 'United States', "Athletics Men's 4 x 400 metres Relay"),
#  ('Angelo Mazzoni', 'Italy', "Fencing Men's epee, Team"),
#  ('Marnie Elizabeth McBean', 'Canada', "Rowing Women's Double Sculls"),
#  ('Katrina Felicia McClain (-Johnson)', 'United States', "Basketball Women's Basketball"),
#  ('Nikki Kensengane McCray', 'United States', "Basketball Women's Basketball"),
#  ('Carla Renee McGhee', 'United States', "Basketball Women's Basketball"),
#  ('Michael Scott "Mike" McKay', 'Australia', "Rowing Men's Coxless Fours"),
#  ('Ioannis Melissanidis', 'Greece', "Gymnastics Men's Floor Exercise"),
#  ('Yury Vasilyevich Melnichenko', 'Kazakhstan', "Wrestling Men's Bantamweight, Greco-Roman"),
#  ('Zoran Mikuli', 'Croatia', "Handball Men's Handball"),
#  ('Tiffeny Carleen Milbrett', 'United States', "Football Women's Football"),
#  ('Jearl Atawa Miles-Clark', 'United States', "Athletics Women's 4 x 400 metres Relay"),
#  ('Inger Z. Miller', 'United States', "Athletics Women's 4 x 100 metres Relay"),
#  ('Reginald Wayne "Reggie" Miller', 'United States', "Basketball Men's Basketball"),
#  ('Shannon Lee Miller (-Phillips, -Falconetti)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Shannon Lee Miller (-Phillips, -Falconetti)', 'United States', "Gymnastics Women's Balance Beam"),
#  ('Derek Bruce Mills', 'United States', "Athletics Men's 4 x 400 metres Relay"),
#  ('Dominique Helena Moceanu (-Canales)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Jean-Michel Monin', 'France', "Cycling Men's Team Pursuit, 4,000 metres"),
#  ('Eliecer Montes de Oca Fleitas', 'Cuba', "Baseball Men's Baseball"),
#  ('Noureddine Morceli', 'Algeria', "Athletics Men's 1,500 metres"),
#  ('Francis Georges Henri Moreau', 'France', "Cycling Men's Team Pursuit, 4,000 metres"),
#  ('Sophie Michle Moresse-Pichot', 'France', "Fencing Women's epee, Team"),
#  ('Ivn Moro Fernndez', 'Spain', "Water Polo Men's Water Polo"),
#  ('Jennifer Lynn "Jenny" Morris', 'Australia', "Hockey Women's Hockey"),
#  ('Manuela Mucke', 'Germany', "Canoeing Women's Kayak Fours, 500 metres"),
#  ('Xeno Mller', 'Switzerland', "Rowing Men's Single Sculls"),
#  ('Halil Mutlu', 'Turkey', "Weightlifting Men's Flyweight"),
#  ('Alvaro Nainovi', 'Croatia', "Handball Men's Handball"),
#  ('Kenzo Nakamura', 'Japan', "Judo Men's Lightweight"),
#  ('Ludmila Viktorovna Narozhilenko-Engquist (Leonova-)', 'Sweden', "Athletics Women's 100 metres Hurdles"),
#  ('Pawe Marian Nastula', 'Poland', "Judo Men's Half-Heavyweight"),
#  ('Armen Lyudvikovich Nazaryan', 'Armenia', "Wrestling Men's Flyweight, Greco-Roman"),
#  ('Aleksey Yuryevich Nemov', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Aleksey Yuryevich Nemov', 'Russia', "Gymnastics Men's Horse Vault"),
#  ('Lars Nieberg', 'Germany', 'Equestrianism Mixed Jumping, Team'),
#  ('Yelena Nikolayevna Nikolayeva (Kuznetsova-)', 'Russia', "Athletics Women's 10 kilometres Walk"),
#  ('Vnuste Niyongabo', 'Burundi', "Athletics Men's 5,000 metres"),
#  ('Tadahiro Nomura', 'Japan', "Judo Men's Extra-Lightweight"),
#  ('Daniel Dion "Dan" O\'Brien', 'United States', "Athletics Men's Decathlon"),
#  ("Leah Marie O'Brien-Amico", 'United States', "Softball Women's Softball"),
#  ('Abiodun Olugbemiga Obafemi', 'Nigeria', "Football Men's Football"),
#  ('Miguel ngel "Miki" Oca Gaia', 'Spain', "Water Polo Men's Water Polo"),
#  ("Raisa Mirelda O'Farrill Bolanos", 'Cuba', "Volleyball Women's Volleyball"),
#  ('Uche Alozie Okechukwu', 'Nigeria', "Football Men's Football"),
#  ('Augustine Azuka "Jay-Jay" Okocha', 'Nigeria', "Football Men's Football"),
#  ('Hakeem Abdul Olajuwon', 'United States', "Basketball Men's Basketball"),
#  ('Elisabeta Oleniuc-Lip', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Sunday Ogorchukwu Oliseh', 'Nigeria', "Football Men's Football"),
#  ("V'iacheslav Mykolaiovych Oliynyk", 'Ukraine', "Wrestling Men's Light-Heavyweight, Greco-Roman"),
#  ('Jon C. Olsen', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Jon C. Olsen', 'United States', "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  ('Ioana Olteanu (Clin-)', 'Romania', "Rowing Women's Coxed Eights"),
#  ("Shaquille Rashuan O'Neal", 'United States', "Basketball Men's Basketball"),
#  ('Susan "Susie" O\'Neill', 'Australia', "Swimming Women's 200 metres Butterfly"),
#  ('Mobi Patrick Oparaku', 'Nigeria', "Football Men's Football"),
#  ('Wilson Oruma', 'Nigeria', "Football Men's Football"),
#  ('Carla Overbeck (Werden-)', 'United States', "Football Women's Football"),
#  ('Antonio Pacheco Mass', 'Cuba', "Baseball Men's Baseball"),
#  ('Juan Padilla Alfonso', 'Cuba', "Baseball Men's Baseball"),
#  ('Denis Vladimirovich Pankratov', 'Russia', "Swimming Men's 100 metres Butterfly"),
#  ('Denis Vladimirovich Pankratov', 'Russia', "Swimming Men's 200 metres Butterfly"),
#  ('Eduardo Paret Prez', 'Cuba', "Baseball Men's Baseball"),
#  ('Cynthia Marie "Cindy" Parlow', 'United States', "Football Women's Football"),
#  ('Aleksandr "Alex" Parygin', 'Kazakhstan', "Modern Pentathlon Men's Individual"),
#  ('Vladislav Yuryevich Pavlovich', 'Russia', "Fencing Men's Foil, Team"),
#  ('Jorge "Jordi" Pay Rodrguez', 'Spain', "Water Polo Men's Water Polo"),
#  ('Gary Dwayne Payton', 'United States', "Basketball Men's Basketball"),
#  ('Heather M. Pease-Olson', 'United States', "Synchronized Swimming Women's Team"),
#  ('Sergio Pedrerol Cavalle', 'Spain', "Water Polo Men's Water Polo"),
#  ('Marie-Jos Juliana Prec (Hontas-)', 'France', "Athletics Women's 200 metres"),
#  ('Marie-Jos Juliana Prec (Hontas-)', 'France', "Athletics Women's 400 metres"),
#  ('Jacqueline Margaret "Jackie" Pereira', 'Australia', "Hockey Women's Hockey"),
#  ('Jefferson Leonardo Prez Quezada', 'Ecuador', "Athletics Men's 20 kilometres Walk"),
#  ('Nova Maree Peris-Kneebone (-Batman, -Appleton)', 'Australia', "Hockey Women's Hockey"),
#  ('Kieren John Perkins', 'Australia', "Swimming Men's 1,500 metres Freestyle"),
#  ('Goran Perkovac', 'Croatia', "Handball Men's Handball"),
#  ('Aleksey Aleksandrovich Petrov', 'Russia', "Weightlifting Men's Middle-Heavyweight"),
#  ('Paola Pezzo', 'Italy', "Cycling Women's Mountainbike, Cross-Country"),
#  ('Jaycie Lynn Phelps (-McClure, -Marus)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Matthew Clive Pinsent', 'Great Britain', "Rowing Men's Coxless Pairs"),
#  ('Constana Pipot-Burcic', 'Romania', "Rowing Women's Lightweight Double Sculls"),
#  ('Scottie Maurice Pippen', 'United States', "Basketball Men's Basketball"),
#  ('Yevgeny Anatolyevich Podgorny', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Liliya Oleksandrivna Podkopaieva (-Nahorniy)', 'Ukraine', "Gymnastics Women's Individual All-Around"),
#  ('Liliya Oleksandrivna Podkopaieva (-Nahorniy)', 'Ukraine', "Gymnastics Women's Floor Exercise"),
#  ('Claudia Mara Poll Ahrens', 'Costa Rica', "Swimming Women's 200 metres Freestyle"),
#  ('Marioara Popescu-Ciobanu', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Aleksandr Vladimirovich Popov', 'Russia', "Swimming Men's 50 metres Freestyle"),
#  ('Aleksandr Vladimirovich Popov', 'Russia', "Swimming Men's 100 metres Freestyle"),
#  ('Ramona Portwich', 'Germany', "Canoeing Women's Kayak Fours, 500 metres"),
#  ('Jan Marcus Posthuma', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Thomas Poulsen', 'Denmark', "Rowing Men's Lightweight Coxless Fours"),
#  ('Katrina Maree "Triny" Powell', 'Australia', "Hockey Women's Hockey"),
#  ('Lisa Josephine Powell-Carruthers', 'Australia', "Hockey Women's Hockey"),
#  ('Stanislav Alekseyevich Pozdnyakov', 'Russia', "Fencing Men's Sabre, Individual"),
#  ('Stanislav Alekseyevich Pozdnyakov', 'Russia', "Fencing Men's Sabre, Team"),
#  ('Iztok Puc', 'Croatia', "Handball Men's Handball"),
#  ('Alessandro Puccini', 'Italy', "Fencing Men's Foil, Individual"),
#  ('Qiao Hong', 'China-1', "Table Tennis Women's Doubles"),
#  ('Kristine Lora Quance (-Julian)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Udo Gnther Quellmalz', 'Germany', "Judo Men's Half-Lightweight"),
#  ('Maurizio Randazzo', 'Italy', "Fencing Men's epee, Team"),
#  ('Lene Rantala', 'Denmark', "Handball Women's Handball"),
#  ('Heli Orvokki Rantanen', 'Finland', "Athletics Women's Javelin Throw"),
#  ('Stephen Geoffrey "Steven" Redgrave', 'Great Britain', "Rowing Men's Coxless Pairs"),
#  ('David Terrell Reid', 'United States', "Boxing Men's Light-Middleweight"),
#  ('Thomas Reineck', 'Germany', "Canoeing Men's Kayak Fours, 1,000 metres"),
#  ('Marie-Claire Restoux', 'France', "Judo Women's Half-Lightweight"),
#  ('Kimberly Susan "Kim" Rhode (-Harryman)', 'United States', "Shooting Women's Double Trap"),
#  ('Maria Fernanda Moreira Ribeiro', 'Portugal', "Athletics Women's 10,000 metres"),
#  ('Pascal Richard', 'Switzerland', "Cycling Men's Road Race, Individual"),
#  ('Dorothy Gay "Dot" Richardson', 'United States', "Softball Women's Softball"),
#  ('Mitchell James "Mitch" Richmond, III', 'United States', "Basketball Men's Basketball"),
#  ('Lars Peter Riedel', 'Germany', "Athletics Men's Discus Throw"),
#  ('Nicolaas Hessel "Nico" Rienks', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Fatuma Roba', 'Ethiopia', "Athletics Women's Marathon"),
#  ('Tiffany Marie Roberts (-Sahaydak)', 'United States', "Football Women's Football"),
#  ('David Maurice Robinson', 'United States', "Basketball Men's Basketball"),
#  ('Danielle "Danni" Roche', 'Australia', "Hockey Women's Hockey"),
#  ('Vebjrn Rodal', 'Norway', "Athletics Men's 800 metres"),
#  ('Engelbrecht "Brecht" Rodenburg', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Jess Miguel Rolln Prada', 'Spain', "Water Polo Men's Water Polo"),
#  ('Gillian Rolton', 'Australia', 'Equestrianism Mixed Three-Day Event, Team'),
#  ('Maikro Eusebio Romero Esquivel', 'Cuba', "Boxing Men's Flyweight"),
#  ('Ormari Romero Turcas', 'Cuba', "Baseball Men's Baseball"),
#  ('Antonio Rossi', 'Italy', "Canoeing Men's Kayak Singles, 500 metres"),
#  ('Antonio Rossi', 'Italy', "Canoeing Men's Kayak Doubles, 1,000 metres"),
#  ('Kristine Roug', 'Denmark', "Sailing Women's One Person Dinghy"),
#  ('Jeffrey Norman "Jeff" Rouse', 'United States', "Swimming Men's 100 metres Backstroke"),
#  ('Jeffrey Norman "Jeff" Rouse', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Jason Rouser', 'United States', "Athletics Men's 4 x 400 metres Relay"),
#  ('Florian Georges Philippe Rousseau', 'France', "Cycling Men's 1,000 metres Time Trial"),
#  ('Norbert Rzsa', 'Hungary', "Swimming Men's 200 metres Breaststroke"),
#  ('Yumilka Ruz Luaces', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Katrin Rutschow-Stomporowski', 'Germany', "Rowing Women's Quadruple Sculls"),
#  ('Oleg Elekpayevich Saitov', 'Russia', "Boxing Men's Welterweight"),
#  ('Annette Elizabeth Salmeen', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Sandra Tavares Pires Nascimento', 'Brazil-1', "Beach Volleyball Women's Beach Volleyball"),
#  ('Jordi Sans Juan', 'Spain', "Water Polo Men's Water Polo"),
#  ('Carles Sanz Lpez', 'Spain', "Water Polo Men's Water Polo"),
#  ('Zlatko "Zlatan" Saraevi', 'Croatia', "Handball Men's Handball"),
#  ('Dmitry Ivanovich Sautin', 'Russia', "Diving Men's Platform"),
#  ('Jill Savery', 'United States', "Synchronized Swimming Women's Team"),
#  ('Flix Savn Fabr', 'Cuba', "Boxing Men's Heavyweight"),
#  ('Buvaysar Khamidovich Saytiyev', 'Russia', "Wrestling Men's Welterweight, Freestyle"),
#  ('Daniele Scarpa', 'Italy', "Canoeing Men's Kayak Doubles, 1,000 metres"),
#  ('Wendy Lynn Schaeffer', 'Australia', 'Equestrianism Mixed Three-Day Event, Team'),
#  ('Martin Schaudt', 'Germany', 'Equestrianism Mixed Dressage, Team'),
#  ('Robert Scheidt', 'Brazil', 'Sailing Mixed One Person Dinghy'),
#  ('Nathalie Schneyder (-Bartleson)', 'United States', "Synchronized Swimming Women's Team"),
#  ('Anett Schuck', 'Germany', "Canoeing Women's Kayak Fours, 500 metres"),
#  ('Richard "Rich" Schuil', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Bradley Darrell Schumacher', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Bradley Darrell Schumacher', 'United States', "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  ('Jochen Schmann', 'Germany', 'Sailing Mixed Three Person Keelboat'),
#  ('Ralf Schumann', 'Germany', "Shooting Men's Rapid-Fire Pistol, 25 metres"),
#  ('William Douglas "Tripp" Schwenk, III', 'United States', "Swimming Men's 4 x 100 metres Medley Relay"),
#  ('Antonio Scull Hernndez', 'Cuba', "Baseball Men's Baseball"),
#  ('Briana Collette Scurry', 'United States', "Football Women's Football"),
#  ('Kateryna Olehivna Serebrianska', 'Ukraine', "Rhythmic Gymnastics Women's Individual"),
#  ('Sergey Aleksandrovich Sharikov', 'Russia', "Fencing Men's Sabre, Team"),
#  ('Rustam Khalimdzhanovych Sharipov', 'Ukraine', "Gymnastics Men's Parallel Bars"),
#  ('Dmitry Stepanovich Shevchenko', 'Russia', "Fencing Men's Foil, Team"),
#  ('Ghada Shouaa', 'Syria', "Athletics Women's Heptathlon"),
#  ('Jacqueline Louise "Jackie" da Cruz Silva', 'Brazil-1', "Beach Volleyball Women's Beach Volleyball"),
#  ('Sim Gwon-Ho', 'South Korea', "Wrestling Men's Light-Flyweight, Greco-Roman"),
#  ('Heather Lee Simmons-Carrasco', 'United States', "Synchronized Swimming Women's Team"),
#  ('Diederik Rudolf Simon', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Kate Elizabeth Slatter (-Allen)', 'Australia', "Rowing Women's Coxless Pairs"),
#  ('Franke Sloothaak', 'Germany', 'Equestrianism Mixed Jumping, Team'),
#  ('Irfan Smajlagi', 'Croatia', "Handball Men's Handball"),
#  ('Julie M. Smith', 'United States', "Softball Women's Softball"),
#  ('LaMont Smith', 'United States', "Athletics Men's 4 x 400 metres Relay"),
#  ('Michele Mary Smith', 'United States', "Softball Women's Softball"),
#  ('Michelle Marie Smith (-De Bruin)', 'Ireland', "Swimming Women's 400 metres Freestyle"),
#  ('Michelle Marie Smith (-De Bruin)', 'Ireland', "Swimming Women's 200 metres Individual Medley"),
#  ('Michelle Marie Smith (-De Bruin)', 'Ireland', "Swimming Women's 400 metres Individual Medley"),
#  ('Hocine Soltani', 'Algeria', "Boxing Men's Lightweight"),
#  ('Jana Sorgers (-Rau)', 'Germany', "Rowing Women's Quadruple Sculls"),
#  ('Doina Tudora Sprcu (-Craciun)', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Dawn Michelle Staley', 'United States', "Basketball Women's Basketball"),
#  ('Katherine "Kate" Starre', 'Australia', "Hockey Women's Hockey"),
#  ('Kathryn Suzanne "Katy" Steding', 'United States', "Basketball Women's Basketball"),
#  ('Kent C. Steffes', 'United States-1', "Beach Volleyball Men's Beach Volleyball"),
#  ('Andr Steiner', 'Germany', "Rowing Men's Quadruple Sculls"),
#  ('Rochelle Stevens', 'United States', "Athletics Women's 4 x 400 metres Relay"),
#  ('Megan Leanne Still (-Marcks)', 'Australia', "Rowing Women's Coxless Pairs"),
#  ('John Houston Stockton', 'United States', "Basketball Men's Basketball"),
#  ('Shelly B. Stokes', 'United States', "Softball Women's Softball"),
#  ('Kerri Allyson Strug (-Fischer)', 'United States', "Gymnastics Women's Team All-Around"),
#  ('Ricky Achmad Subagja', 'Indonesia', "Badminton Men's Doubles"),
#  ('Jill Sudduth', 'United States', "Synchronized Swimming Women's Team"),
#  ('Vladimir ujster', 'Croatia', "Handball Men's Handball"),
#  ('Naim Sleymanolu', 'Turkey', "Weightlifting Men's Featherweight"),
#  ('Sun Fuming', 'China', "Judo Women's Heavyweight"),
#  ('Gitte Jensby Sunesen', 'Denmark', "Handball Women's Handball"),
#  ('Bruny Surin', 'Canada', "Athletics Men's 4 x 100 metres Relay"),
#  ('Sheryl Denice Swoopes', 'United States', "Basketball Women's Basketball"),
#  ('Tymur Borysovych Taimazov', 'Ukraine', "Weightlifting Men's Heavyweight II"),
#  ('Robert Blyth Tait', 'New Zealand', 'Equestrianism Mixed Three-Day Event, Individual'),
#  ('Anca Tnase (-Ruican)', 'Romania', "Rowing Women's Coxed Eights"),
#  ('Anne Dorthe Tanderup', 'Denmark', "Handball Women's Handball"),
#  ('Tang Lingsheng', 'China', "Weightlifting Men's Bantamweight"),
#  ('Sheila Christine Taormina', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Cristina Teuscher', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Monica Theodorescu', 'Germany', 'Equestrianism Mixed Dressage, Team'),
#  ('Margot A. Thien', 'United States', "Synchronized Swimming Women's Team"),
#  ('Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Josia Thugwane', 'South Africa', "Athletics Men's Marathon"),
#  ('Davide Tizzano', 'Italy', "Rowing Men's Double Sculls"),
#  ('James Bruce Tomkins', 'Australia', "Rowing Men's Coxless Fours"),
#  ('Liane Marianne Tooth', 'Australia', "Hockey Women's Hockey"),
#  ('Gwendolyn Lenna "Gwen" Torrence (-Waller, -Smith)', 'United States', "Athletics Women's 4 x 100 metres Relay"),
#  ('Regla Radameris Torres Herrera', 'Cuba', "Volleyball Women's Volleyball"),
#  ('Giovanna Trillini', 'Italy', "Fencing Women's Foil, Team"),
#  ('Dmitry Vladimirovich Trush', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Scott Eric Tucker', 'United States', "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  ('Danielle M. "Dani" Tyler', 'United States', "Softball Women's Softball"),
#  ('Luis Ulacia lvarez', 'Cuba', "Baseball Men's Baseball"),
#  ('Melanie M. Valerio', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Sebastiaan Jacques Henri "Bas" van de Goor', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Mike Willem Frank van de Goor', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Taco Hajo van den Honert', 'Netherlands', "Hockey Men's Hockey"),
#  ('Roelof Anttonius "Olof" van der Meulen', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Cornelis Pieter "Niels" van der Zwan', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Amy Deloris Van Dyken (-Rouen)', 'United States', "Swimming Women's 50 metres Freestyle"),
#  ('Amy Deloris Van Dyken (-Rouen)', 'United States', "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  ('Amy Deloris Van Dyken (-Rouen)', 'United States', "Swimming Women's 100 metres Butterfly"),
#  ('Amy Deloris Van Dyken (-Rouen)', 'United States', "Swimming Women's 4 x 100 metres Medley Relay"),
#  ('Tycho van Meer', 'Netherlands', "Hockey Men's Hockey"),
#  ('Wouter van Pelt', 'Netherlands', "Hockey Men's Hockey"),
#  ('Niels Henning van Steenis', 'Netherlands', "Rowing Men's Coxed Eights"),
#  ('Remco van Wijk', 'Netherlands', "Hockey Men's Hockey"),
#  ('Lzaro Vargas lvarez', 'Cuba', "Baseball Men's Baseball"),
#  ('Dmitry Andreyevich Vasilenko', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Stephan Patrick Veen', 'Netherlands', "Hockey Men's Hockey"),
#  ('Tisha Lea Venturini', 'United States', "Football Women's Football"),
#  ('Maria Valentina Vezzali', 'Italy', "Fencing Women's Foil, Team"),
#  ('Begoa Va Dufresne Perea', 'Spain', "Sailing Women's Two Person Dinghy"),
#  ('Hctor Vinent Chron', 'Cuba', "Boxing Men's Light-Welterweight"),
#  ('Augustinus Wilhelmus Johannes Marines "Guus" Vogels', 'Netherlands', "Hockey Men's Hockey"),
#  ('Stephan Volkert', 'Germany', "Rowing Men's Quadruple Sculls"),
#  ('Aleksey Nikolayevich Voropayev', 'Russia', "Gymnastics Men's Team All-Around"),
#  ('Wang Junxia', 'China', "Athletics Women's 5,000 metres"),
#  ('Andreas Wecker', 'Germany', "Gymnastics Men's Horizontal Bar"),
#  ('Ulla Werbrouck', 'Belgium', "Judo Women's Half-Heavyweight"),
#  ('Isabelle Regina Werth', 'Germany', 'Equestrianism Mixed Dressage, Individual'),
#  ('Isabelle Regina Werth', 'Germany', 'Equestrianism Mixed Dressage, Team'),
#  ('Taribo West', 'Nigeria', "Football Men's Football"),
#  ('Rodney E. "Rod" White', 'United States', "Archery Men's Team"),
#  ('Ashley Ann Whitney', 'United States', "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  ('Linnea Susanne Wiberg-Gunnarsson', 'Sweden', "Canoeing Women's Kayak Doubles, 500 metres"),
#  ('Christa Lee Williams', 'United States', "Softball Women's Softball"),
#  ('Andr Willms', 'Germany', "Rowing Men's Quadruple Sculls"),
#  ('Linetta A. Wilson', 'United States', "Athletics Women's 4 x 400 metres Relay"),
#  ('Staci Nicole Wilson', 'United States', "Football Women's Football"),
#  ('Olaf Winter', 'Germany', "Canoeing Men's Kayak Fours, 1,000 metres"),
#  ('Ryszard Marcin Wolny', 'Poland', "Wrestling Men's Lightweight, Greco-Roman"),
#  ('Todd Andrew Woodbridge', 'Australia', "Tennis Men's Doubles"),
#  ('Mark Raymond Woodforde', 'Australia', "Tennis Men's Doubles"),
#  ('Andrzej Wroski', 'Poland', "Wrestling Men's Heavyweight, Greco-Roman"),
#  ('Ilke Wyludda', 'Germany', "Athletics Women's Discus Throw"),
#  ('Xiong Ni', 'China', "Diving Men's Springboard"),
#  ('Yang Ling', 'China', "Shooting Men's Running Target, 10 metres"),
#  ('Hamza Yerlikaya', 'Turkey', "Wrestling Men's Middleweight, Greco-Roman"),
#  ('Valentin Dimitrov Yordanov', 'Bulgaria', "Wrestling Men's Flyweight, Freestyle"),
#  ('Yun Hye-Yeong', 'South Korea', "Archery Women's Team"),
#  ('Mark Zabel', 'Germany', "Canoeing Men's Kayak Fours, 1,000 metres"),
#  ('Theresa Zabell Lucas', 'Spain', "Sailing Women's Two Person Dinghy"),
#  ('Zulfiya Khasanovna Zabirova', 'Russia', "Cycling Women's Individual Time Trial"),
#  ('Wodzimierz Jan Zawadzki', 'Poland', "Wrestling Men's Featherweight, Greco-Roman"),
#  ('Jan elezn', 'Czech Republic', "Athletics Men's Javelin Throw"),
#  ('Zhan Xugang', 'China', "Weightlifting Men's Lightweight"),
#  ('Vasily Valeryevich Zhirov', 'Kazakhstan', "Boxing Men's Light-Heavyweight"),
#  ('Ronald Ferdinand "Ron" Zwerver', 'Netherlands', "Volleyball Men's Volleyball"),
#  ('Henk Jan Zwolle', 'Netherlands', "Rowing Men's Coxed Eights")]

# %% [markdown]
# ### 6. SQL query that selects the first and last years of summer olympics.

# %%
# %%sql
# select min(year) as first_year, max(year) as last_year
# from Medal_type;
# Out:
# *  sqlite:///database.db
# Done.
# [(1896, 2020)]

# %% [markdown]
# ### 7. SQL query that selects the average age of female and male athletes who won a medal?

# %%
# %%sql
# select sex, AVG(age) AS avg_age
# from Player,Medal_type
# where Player.Player_id=Medal_type.Player_id
# and medal IS NOT NULL
# GROUP BY sex
# Out:
# *  sqlite:///database.db
# Done.
# [('F', 24.670602125147578), ('M', 26.541530293112228)]

# %% [markdown]
# ### 8. SQL query that selects the event in which women have participated most?

# %%
# %%sql
# select sex,event,count(sex) as max,Year
# from Player,Match,Medal_type
# where Player.player_id=Match.player_id
# and Player.player_id=Medal_type.player_id
# and Sex='F'
# group by Event
# Order by max desc
# limit 1;
# Out:
# *  sqlite:///database.db
# Done.
# [('F', 'Women Team', 2925, 2012)]

# %% [markdown]
# ### 9. SQL query that selects top 5 sports in which female athletes are more interested ?

# %%
# %%sql
# select sport, COUNT(medal) AS medal_count,sex
# from Match,Medal_type,player
# where Match.player_id=Medal_type.player_id
# and Match.player_id=player.player_id
# and sex = 'F'
# Group by sport
# ORDER BY medal_count DESC
# LIMIT 5;
# Out:
# *  sqlite:///database.db
# Done.
# [('Athletics', 2037, 'F'),
#  ('Swimming', 1860, 'F'),
#  ('Rowing', 969, 'F'),
#  ('Gymnastics', 898, 'F'),
#  ('Hockey', 664, 'F')]

# %% [markdown]
# ### 10. SQL query that selects the team which has won the most gold medal.return the count of medals and the year

# %%
# %%sql
# select team,COUNT(Medal) AS mdal_won, year
# from country,Medal_type
# where country.team_id=Medal_type.player_id
# and medal='Gold'
# GROUP BY team
# ORDER BY medal_won DESC
# LIMIT 1
# Out:
# *  sqlite:///database.db
# Done.
# [('United States', 2503, 1900)]
